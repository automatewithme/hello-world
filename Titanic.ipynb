# %% [raw]
# Importing Data

# %%
import pandas as pd
import numpy as np
import pylab as plt
train_data=pd.read_csv("train.csv", na_values="n/a")

# %% [raw]
# Data Exploration and Preparation it Machine Learning

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
gender=sorted(train_data['Sex'].unique())
genders_mapping=dict(zip(gender, range(0, len(gender) + 1)))
genders_mapping
# Out:
# {'female': 0, 'male': 1}

# %%
train_data['Gender_Val']=train_data['Sex'].map(genders_mapping).astype(int)
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender_Val
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Gender_Val     891 non-null int32
# dtypes: float64(2), int32(1), int64(5), object(5)
# memory usage: 69.6+ KB

# %%
train_data['Embarked']=train_data['Embarked'].fillna(value='S')

# %%
train_data[train_data['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Gender_Val]
# Index: []

# %%
train_data[train_data['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
# Get the unique values of Embarked
embarked_locs = sorted(train_data['Embarked'].unique())

embarked_locs_mapping = dict(zip(embarked_locs, 
                                 range(0, len(embarked_locs) + 1)))
embarked_locs_mapping
# Out:
# {'C': 0, 'Q': 1, 'S': 2}

# %%
train_data['Embarked_Val'] = train_data['Embarked'] \
                               .map(embarked_locs_mapping) \
                               .astype(int)
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender_Val  Embarked_Val
# 0      0         A/5 21171   7.2500   NaN        S           1             2
# 1      0          PC 17599  71.2833   C85        C           0             0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0             2
# ...

# %%
embarked_locs = sorted(train_data['Embarked_Val'].unique())
embarked_locs
# Out:
# [0, 1, 2]

# %%
if len(train_data[train_data['Embarked'].isnull()] > 0):
    train_data.replace({'Embarked_Val' : 
                   { embarked_locs_mapping[nan] : embarked_locs_mapping['S'] 
                   }
               }, 
               inplace=True)

# %%
train_data = pd.concat([train_data, pd.get_dummies(train_data['Embarked_Val'], prefix='Embarked_Val')], axis=1)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender_Val  Embarked_Val  \
# 0      0         A/5 21171   7.2500   NaN        S           1             2
# 1      0          PC 17599  71.2833   C85        C           0             0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0             2
# ...

# %%
train_data[train_data['Age'].isnull()][['Sex', 'Pclass', 'Age']].head()
# Out:
#        Sex  Pclass  Age
# 5     male       3  NaN
# 17    male       2  NaN
# 19  female       3  NaN
# 26    male       3  NaN
# 28  female       3  NaN

# %%
# To keep Age in tact, make a copy of it called AgeFill 
# that we will use to fill in the missing ages:
train_data['AgeFill'] = train_data['Age']

# Populate AgeFill
train_data['AgeFill'] = train_data['AgeFill'] \
                        .groupby([train_data['Gender_Val'], train_data['Pclass']]) \
                        .apply(lambda x: x.fillna(x.median()))

# %%
len(train_data[train_data['AgeFill'].isnull()])
# Out:
# 0

# %%
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch']
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender_Val  Embarked_Val  \
# 0      0         A/5 21171   7.2500   NaN        S           1             2
# 1      0          PC 17599  71.2833   C85        C           0             0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0             2
# ...

# %%
train_data.dtypes[train_data.dtypes.map(lambda x: x == 'object')]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
train_data = train_data.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], 
                         axis=1)

# %%
train_data = train_data.drop(['Age', 'SibSp', 'Parch', 'PassengerId', 'Embarked_Val'], axis=1)
train_data.dtypes
# Out:
# Survived            int64
# Pclass              int64
# Fare              float64
# Gender_Val          int32
# Embarked_Val_0      uint8
# Embarked_Val_1      uint8
# Embarked_Val_2      uint8
# AgeFill           float64
# FamilySize          int64
# dtype: object

# %%
data_train = train_data.values
data_train
# Out:
# array([[  0.    ,   3.    ,   7.25  , ...,   1.    ,  22.    ,   1.    ],
#        [  1.    ,   1.    ,  71.2833, ...,   0.    ,  38.    ,   1.    ],
#        [  1.    ,   3.    ,   7.925 , ...,   1.    ,  26.    ,   0.    ],
#        ...,
#        [  0.    ,   3.    ,  23.45  , ...,   1.    ,  21.5   ,   3.    ],
#        [  1.    ,   1.    ,  30.    , ...,   0.    ,  26.    ,   0.    ],
#        [  0.    ,   3.    ,   7.75  , ...,   0.    ,  32.    ,   0.    ]])

# %% [raw]
# Training Different Models

# %%
# Training data features, skip the first column 'Survived'
train_features = data_train[:, 1:]

# 'Survived' column values
train_target = data_train[:, 0]

# %%
from sklearn import svm
clf=svm.SVR()
# Fit the model to our training data
clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)
"Mean accuracy of Support Vector Machines: {0}".format(score)
# Out:
# 'Mean accuracy of Support Vector Machines: 0.7334585725745201'

# %%
import sklearn
clf1=sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)
clf1.fit(train_features, train_target)
score2=clf1.score(train_features, train_target)
"Mean accuracy of K-Nearest Neighbors: {0}".format(score2)
# Out:
# 'Mean accuracy of K-Nearest Neighbors: 0.5549803470424695'

# %%
from sklearn.linear_model import LinearRegression
lin_model=LinearRegression()
lin=lin_model.fit(train_features, train_target)
score1 = lin.score(train_features, train_target)
"Mean accuracy of Linear Model: {0}".format(score1)
# Out:
# 'Mean accuracy of Linear Model: 0.39937849413988713'

# %%
from sklearn.ensemble import RandomForestClassifier
clf2 = RandomForestClassifier(n_estimators=100)
clf2 = clf2.fit(train_features, train_target)
score = clf2.score(train_features, train_target)
"Mean accuracy of Random Forest: {0}".format(score)
# Out:
# 'Mean accuracy of Random Forest: 0.9809203142536476'

# %% [raw]
# Predicting Survivors and saving it to '.csv' file

# %%
data_test = pd.read_csv('test.csv')
data_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
def clean_data(df, drop_passenger_id):
    
    # Get the unique values of Sex
    sexes = sorted(df['Sex'].unique())
    
    # Generate a mapping of Sex from a string to a number representation    
    genders_mapping = dict(zip(sexes, range(0, len(sexes) + 1)))

    # Transform Sex from a string to a number representation
    df['Sex_Val'] = df['Sex'].map(genders_mapping).astype(int)
    
    # Get the unique values of Embarked
    embarked_locs = sorted(df['Embarked'].unique())

    # Generate a mapping of Embarked from a string to a number representation        
    embarked_locs_mapping = dict(zip(embarked_locs, 
                                     range(0, len(embarked_locs) + 1)))
    
    # Transform Embarked from a string to dummy variables
    df = pd.concat([df, pd.get_dummies(df['Embarked'], prefix='Embarked_Val')], axis=1)
    
    # Fill in missing values of Embarked
    # Since the vast majority of passengers embarked in 'S': 3, 
    # we assign the missing values in Embarked to 'S':
    if len(df[df['Embarked'].isnull()] > 0):
        df.replace({'Embarked_Val' : 
                       { embarked_locs_mapping[nan] : embarked_locs_mapping['S'] 
                       }
                   }, 
                   inplace=True)
    
    # Fill in missing values of Fare with the average Fare
    if len(df[df['Fare'].isnull()] > 0):
        avg_fare = df['Fare'].mean()
        df.replace({ None: avg_fare }, inplace=True)
    
    # To keep Age in tact, make a copy of it called AgeFill 
    # that we will use to fill in the missing ages:
    df['AgeFill'] = df['Age']

    # Determine the Age typical for each passenger class by Sex_Val.  
    # We'll use the median instead of the mean because the Age 
    # histogram seems to be right skewed.
    df['AgeFill'] = df['AgeFill'] \
                        .groupby([df['Sex_Val'], df['Pclass']]) \
                        .apply(lambda x: x.fillna(x.median()))
            
    # Define a new feature FamilySize that is the sum of 
    # Parch (number of parents or children on board) and 
    # SibSp (number of siblings or spouses):
    df['FamilySize'] = df['SibSp'] + df['Parch']
    
    # Drop the columns we won't use:
    df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)
    
    # Drop the Age column since we will be using the AgeFill column instead.
    # Drop the SibSp and Parch columns since we will be using FamilySize.
    # Drop the PassengerId column since it won't be used as a feature.
    df = df.drop(['Age', 'SibSp', 'Parch'], axis=1)
    
    if drop_passenger_id:
        df = df.drop(['PassengerId'], axis=1)
    
    return df

# %%
# Data wrangle the test set and convert it to a numpy array
data_test = clean_data(data_test, drop_passenger_id=False)
test_data = data_test.values

# %%
test_data
# Out:
# array([[  8.92000000e+02,   3.00000000e+00,   7.82920000e+00, ...,
#           0.00000000e+00,   3.45000000e+01,   0.00000000e+00],
#        [  8.93000000e+02,   3.00000000e+00,   7.00000000e+00, ...,
#           1.00000000e+00,   4.70000000e+01,   1.00000000e+00],
#        [  8.94000000e+02,   2.00000000e+00,   9.68750000e+00, ...,
#           0.00000000e+00,   6.20000000e+01,   0.00000000e+00],
#        ...,
#        [  1.30700000e+03,   3.00000000e+00,   7.25000000e+00, ...,
#           1.00000000e+00,   3.85000000e+01,   0.00000000e+00],
#        [  1.30800000e+03,   3.00000000e+00,   8.05000000e+00, ...,
#           1.00000000e+00,   3.56271885e+01,   0.00000000e+00],
#        [  1.30900000e+03,   3.00000000e+00,   2.23583000e+01, ...,
#           0.00000000e+00,   3.56271885e+01,   2.00000000e+00]])

# %%
# Get the test data features, skipping the first column 'PassengerId'
test_x = test_data[:, 1:]

# Predict the Survival values for the test data
test_y = clf2.predict(test_x)

# %%
data_test['Survived'] = test_y
data_test[['PassengerId', 'Survived']] \
    .to_csv('algor.csv', index=False)
